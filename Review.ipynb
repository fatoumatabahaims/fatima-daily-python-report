# %%
my_name="Fatoumata"
my_age=12
my_heigth=1.85
print(my_heigth)
# Out:
# 1.85

# %%
my_heigth
# Out:
# 1.85

# %%
type(my_age)
# Out:
# int

# %%
my_first_name="Fatoumata"
my_last_name="Gaba"
print("My full name is", my_first_name+ " " +my_last_name)
# Out:
# My full name is Fatoumata Gaba

# %%
str(my_age) + my_first_name
# Out:
# '12Fatoumata'

# %%
my_first_name[0]
# Out:
# 'F'

# %%
my_list= [my_age,my_first_name,my_last_name, my_heigth]
my_list
# Out:
# [12, 'Fatoumata', 'Gaba', 1.85]

# %%
my_list[2]
# Out:
# 'Gaba'

# %%
my_dict={'a':my_age, 'b':my_heigth}
my_dict
# Out:
# {'a': 12, 'b': 1.85}

# %%
for i in my_list:
    if str(i)>=str(0):
        print(i)
# Out:
# 12
# Fatoumata
# Gaba
# 1.85

# %%
"y"<='0'
# Out:
# False

# %%
"y"<='z'
# Out:
# True

# %%
def square(x):
    return x*x

# %%
square(5)é
# Out:
# 25
