# %%
my_first_list=["Fatima", "Bah", 35]
print(my_first_list)
# Out:
# ['Fatima', 'Bah', '35']

# %%
type(my_first_list)
# Out:
# list

# %%
my_second_list=["Lamine", "Bah", 15]
my_third_list=["Seydina", "Diao", 41]
my_family=print(my_first_list, my_second_list, my_third_list)
# Out:
# ['Fatima', 'Bah', '35'] ['Lamine', 'Bah', '15'] ['Seydina', 'Diao', '41']

# %%
my_family_1=[my_first_list, "safietou", "Diallo", 23]
my_family_1
# Out:
# [['Fatima', 'Bah', '35'], 'safietou', 'Diallo', 23]

# %%
my_family_1[0]
# Out:
# ['Fatima', 'Bah', '35']

# %%
my_family_1[0][-1]
# Out:
# '35'

# %%
my_1=["Lamine", "Bah", 15]
my_2=["Seydina", "Diao", 41]
my_1+my_2
# Out:
# ['Lamine', 'Bah', 15, 'Seydina', 'Diao', 41]

# %%
my_1.extend([6])
my_1
# Out:
# ['Lamine', 'Bah', 15, 6, 6]

# %%
my_1.append([7])
my_1
# Out:
# ['Lamine', 'Bah', 15, 6, 6, [7]]

# %%
2 * my_1
# Out:
# ['Lamine', 'Bah', 15, 6, 6, [7], 'Lamine', 'Bah', 15, 6, 6, [7]]

# %% [markdown]
# 2 * my_1

# %% [markdown]
# ## Dictionary

# %%
my_dict_1={"people1": ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41], "people2": ['Soukay', 'DIA', 41]}
my_dict_1
# Out:
# {'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],
#  'people2': ['Soukay', 'DIA', 41]}

# %%
my_dict_1["people1"]
# Out:
# ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41]

# %%
my_dict_1["people3"]=['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],
my_dict_1
# Out:
# {'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],
#  'people2': ['Soukay', 'DIA', 41],
#  'people3': (['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],)}

# %%
my_dict_2={'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],'people2': ['Soukay', 'DIA', 41],
 'people3': (['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],) ,'people3': (['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],)}

# %%
my_dict_2
# Out:
# {'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],
#  'people2': ['Soukay', 'DIA', 41],
#  'people3': (['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],)}

# %%
my_dict_3={'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],'people2': ['Soukay', 'DIA', 41],
 'people3': (['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],) ,'people3': (['faye', 'fatou', 15, 'Seydina', 'Diao', 41],)}
my_dict_3
# Out:
# {'people1': ['Moctar', 'Diallo', 15, 'Seydina', 'Diao', 41],
#  'people2': ['Soukay', 'DIA', 41],
#  'people3': (['faye', 'fatou', 15, 'Seydina', 'Diao', 41],)}

# %%
my_lelt_dict={"person1": ['Efua', 'Sackey', 15, 41],}
my_right_dict={"person2": ['Moctar', 'Diallo', 15], "person3" :['Khadidiatou', 'Bop', 41],}

# ?my_right_dict.update
# Out:
# Docstring:
# D.update([E, ]**F) -> None.  Update D from mapping/iterable E and F.
# If E is present and has a .keys() method, then does:  for k in E.keys(): D[k] = E[k]
# If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
# In either case, this is followed by: for k in F:  D[k] = F[k]
# Type:      builtin_function_or_method

# %%
my_right_dict.keys()
# Out:
# dict_keys(['person2', 'person3'])

# %%
my_right_dict.update()
